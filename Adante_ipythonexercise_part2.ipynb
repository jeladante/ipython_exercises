# %% [markdown]
# 2.1.1 The on disk databse is used for searching, completeing, and executing previouly-executed commands"
# print "It is also used for persisiting the command history between sessions and loging the input/output history to a file

# %% [markdown]
# "ctrl-p or up-arrow search backward and ctrl-n or down-arrow search forward"

# %% [markdown]
# "2.2.1 In[1] 2 ** 27"
# "      Out[1] 134217728"
# "      In[2] _"
# "      Out[2] 134217728
# the undersocre calls the previous output"

# %% [markdown]
# 2.3 Ipython loging can be turned on by typing %logstart

# %% [markdown]
# 2.3.1 cmd
# 2.3.2 output = !cmd args
# 2.3.3 %bookmark
# 2.3.4 %cd directory
# 2.3.5 %pwd
# 2.3.6 %dhist
# 2.3.7 %env

# %% [markdown]
# 2.4

# %%
my_ip_info = !ifconfig eth0 | grep "inet "

# %%
my_ip_info[0].strip()
# Out:
# 'inet addr:10.0.2.15  Bcast:10.0.2.255  Mask:255.255.255.0'

# %% [markdown]
# 2.5

# %%
# %dhist
# Out:
# Directory history (kept in _dh)
# 0: /home/ubuntu01

# %% [markdown]
# 2.5.1

# %%
# %bookmark ubuntu01

# %% [markdown]
# 2.5.2

# %%
# %alias Hist ubuntu01

# %% [markdown]
# 2.6.1

# %%
# %run ipython-bug.py
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /home/ubuntu01/ipython-bug.py in <module>()
#      10         works_fine()
#      11         throws_an_exception()
# ---> 12 calling_things()
#
# /home/ubuntu01/ipython-bug.py in calling_things()
#       9 def calling_things():
#      10         works_fine()
# ---> 11         throws_an_exception()
#      12 calling_things()
#
# /home/ubuntu01/ipython-bug.py in throws_an_exception()
#       6         a = 5
#       7         b = 6
# ----> 8         assert(a + b == 10)
#       9 def calling_things():
#      10         works_fine()
#
# AssertionError:

# %% [markdown]
# 2.6.2

# %%
# A very large list of strings

strings = ['foo', 'foobar', 'baz', 'qux', 'python', 'Guido Van Rossum'] * 1000000

method1 = [x for x in strings if x.startswith('foo')]

method2 = [x for x in strings if x[:3] == 'foo']

# %%
# %time method1
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.01 µs
# ['foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
# ...

# %%
# %time method2
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 4.05 µs
# ['foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
#  'foobar',
#  'foo',
# ...

# %%
# %timeit method1
# Out:
# 10000000 loops, best of 3: 16.7 ns per loop

# %%
# %timeit method2
# Out:
# 10000000 loops, best of 3: 17.8 ns per loop

# %%
# cprof_example.py

import numpy as np
from numpy.linalg import eigvals

def run_experiment(niter=100):
    Y = 100
    results = []
    
    for _ in xrange(niter):
        mat = np.random.randn(Y, Y)
        max_eigenvalue = np.abs(eigvals(mat)).max()
        results.append(max_eigenvalue)
    return results

some_results = run_experiment()
print 'Largest one we saw: %s' % np.max(some_results)
# Out:
# Largest one we saw: 11.4283983353

# %%
python -m cProfile cprof_example.py
# Out:
#   File "<ipython-input-8-9a3aab209a0a>", line 1
#     python -m cProfile cprof_example.py
#                      ^
# SyntaxError: invalid syntax

# %%
python -m cProfile -s cumulative cprof_example.py
# Out:
#   File "<ipython-input-9-a09f29dd1891>", line 1
#     python -m cProfile -s cumulative cprof_example.py
#                      ^
# SyntaxError: invalid syntax

# %%
# %prun -l some_number -s cumulative run_experiment()

# %%
# %prun -p -s cumulative cprof_example.py
# Out:
# UsageError: option -p not recognized ( allowed: "D:l:rs:T:q" )
